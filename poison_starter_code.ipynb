# %%
# Dependencies
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
# Read CSV

ChildPoisoningsby_Age = pd.read_csv("Resources/ChildPoisoningsbyType_AgeFinal.csv", 
                                    header = [0,1], na_values = "x", skipfooter = 0)
#skiprows = [0,2]                                   

ChildPoisoningsby_Year = pd.read_csv("Resources/ChildPoisoningsbyType_YearFinal.csv",
                                     header = [0,1], na_values = "x", skipfooter = 0)
#skiprows = [0,2]

# %%
ChildPoisoningsby_Age
# Out:
#                                           Age:                       Under 1  \
#                                    Statistics:                         Count
# 0                   Poison/Overdose: All Other                             0
# 1               Poison/Overdose: Drugs/Alcohol                          1481
# 2  Poison/Overdose: Gas/Cleaners/Caustics/etc.                          1125
# 3                          Total for selection                          2606
# 4                                        Rate:         Crude Rate per 100000
# 5                                      Source:  DHSS - MOPHIMS - Injury MICA
# 6                                Generated On:                8/11/2018 6:25
#
#             '1 - 4          '5 - 9        '10 - 14          \
#      Rate    Count    Rate   Count   Rate    Count    Rate
# 0    0.00      0.0    0.00     0.0   0.00      0.0    0.00
# 1  127.64  19655.0  433.44  2396.0  41.36   6425.0  106.25
# 2   96.96   7298.0  160.94  1252.0  21.61   1324.0   21.89
# 3  224.60  26953.0  594.38  3648.0  62.98   7749.0  128.14
# 4     NaN      NaN     NaN     NaN    NaN      NaN     NaN
# 5     NaN      NaN     NaN     NaN    NaN      NaN     NaN
# 6     NaN      NaN     NaN     NaN    NaN      NaN     NaN
#
#   Total for selection
#                 Count    Rate
# 0                 0.0    0.00
# 1             29957.0  170.84
# 2             10999.0   62.73
# 3             40956.0  233.57
# 4                 NaN     NaN
# 5                 NaN     NaN
# 6                 NaN     NaN

# %%
ChildPoisoningsby_Year
# Out:
#                                          Year:  \
#                                    Statistics:
# 0                   Poison/Overdose: All Other
# 1               Poison/Overdose: Drugs/Alcohol
# 2  Poison/Overdose: Gas/Cleaners/Caustics/etc.
# 3                          Total for selection
# 4                                        Rate:
# 5                                      Source:
# 6                                Generated On:
#
#                                                 2001            2002          \
#                                                Count    Rate   Count    Rate
# 0                                                  0    0.00     0.0    0.00
# 1                                               1914  162.65  2040.0  173.71
# 2                                                936   79.54   915.0   77.92
# 3                                               2850  242.19  2955.0  251.63
# 4  Injury rates are annualized per 100000 residents.     NaN     NaN     NaN
# 5                       DHSS - MOPHIMS - Injury MICA     NaN     NaN     NaN
# 6                                     8/11/2018 6:06     NaN     NaN     NaN
#
#      2003            2004            2005   ...      2012            2013  \
#     Count    Rate   Count    Rate   Count   ...     Count    Rate   Count
# 0     0.0    0.00     0.0    0.00     0.0   ...       0.0    0.00     0.0
# 1  1944.0  165.85  2001.0  170.96  2112.0   ...    2157.0  185.00  1843.0
# 2   824.0   70.30   778.0   66.47   851.0   ...     717.0   61.49   694.0
# 3  2768.0  236.15  2779.0  237.43  2963.0   ...    2874.0  246.49  2537.0
# 4     NaN     NaN     NaN     NaN     NaN   ...       NaN     NaN     NaN
# 5     NaN     NaN     NaN     NaN     NaN   ...       NaN     NaN     NaN
# 6     NaN     NaN     NaN     NaN     NaN   ...       NaN     NaN     NaN
#
#              2014            2015         Total for selection
#      Rate   Count    Rate   Count    Rate               Count    Rate
# 0    0.00     0.0    0.00     0.0    0.00                 0.0    0.00
# 1  158.77  1608.0  139.14  1166.0  101.24             29957.0  170.84
# 2   59.79   583.0   50.45   466.0   40.46             10999.0   62.73
# 3  218.55  2191.0  189.58  1632.0  141.71             40956.0  233.57
# 4     NaN     NaN     NaN     NaN     NaN                 NaN     NaN
# 5     NaN     NaN     NaN     NaN     NaN                 NaN     NaN
# 6     NaN     NaN     NaN     NaN     NaN                 NaN     NaN
#
# [7 rows x 33 columns]

# %%
ChildPoisoningsby_Agedrop = ChildPoisoningsby_Age.dropna()
ChildPoisoningsby_Agedrop
# Out:
#                                           Age: Under 1           '1 - 4  \
#                                    Statistics:   Count    Rate    Count
# 0                   Poison/Overdose: All Other       0    0.00      0.0
# 1               Poison/Overdose: Drugs/Alcohol    1481  127.64  19655.0
# 2  Poison/Overdose: Gas/Cleaners/Caustics/etc.    1125   96.96   7298.0
# 3                          Total for selection    2606  224.60  26953.0
#
#            '5 - 9        '10 - 14         Total for selection
#      Rate   Count   Rate    Count    Rate               Count    Rate
# 0    0.00     0.0   0.00      0.0    0.00                 0.0    0.00
# 1  433.44  2396.0  41.36   6425.0  106.25             29957.0  170.84
# 2  160.94  1252.0  21.61   1324.0   21.89             10999.0   62.73
# 3  594.38  3648.0  62.98   7749.0  128.14             40956.0  233.57

# %%
ChildPoisoningsby_Yeardrop = ChildPoisoningsby_Year.dropna()
ChildPoisoningsby_Yeardrop
# Out:
#                                          Year:  2001            2002          \
#                                    Statistics: Count    Rate   Count    Rate
# 0                   Poison/Overdose: All Other     0    0.00     0.0    0.00
# 1               Poison/Overdose: Drugs/Alcohol  1914  162.65  2040.0  173.71
# 2  Poison/Overdose: Gas/Cleaners/Caustics/etc.   936   79.54   915.0   77.92
# 3                          Total for selection  2850  242.19  2955.0  251.63
#
#      2003            2004            2005   ...      2012            2013  \
#     Count    Rate   Count    Rate   Count   ...     Count    Rate   Count
# 0     0.0    0.00     0.0    0.00     0.0   ...       0.0    0.00     0.0
# 1  1944.0  165.85  2001.0  170.96  2112.0   ...    2157.0  185.00  1843.0
# 2   824.0   70.30   778.0   66.47   851.0   ...     717.0   61.49   694.0
# 3  2768.0  236.15  2779.0  237.43  2963.0   ...    2874.0  246.49  2537.0
#
#              2014            2015         Total for selection
#      Rate   Count    Rate   Count    Rate               Count    Rate
# 0    0.00     0.0    0.00     0.0    0.00                 0.0    0.00
# 1  158.77  1608.0  139.14  1166.0  101.24             29957.0  170.84
# 2   59.79   583.0   50.45   466.0   40.46             10999.0   62.73
# 3  218.55  2191.0  189.58  1632.0  141.71             40956.0  233.57
#
# [4 rows x 33 columns]

# %%
# fig = plt.figure(figsize=(12,5))
# ax = plt.subplot()
ChildPoisoningsby_Yeardrop.plot()
ChildPoisoningsby_Agedrop.plot()
#legend.plot("Rate")
#plot.title("ER Poisoning Rates per Age Group")
#plot.legend(loc='best')
#plot.ylabel('Rate/1000')
# xlabel = "Rate"
# ylabel = "Year"
# ax.plt(ChildPoisoningsby_Agedrop)
# ax.plt(ChildPoisoningsby_Agedrop["Rate"])
# ax.grid(True)
# plt.show()

#ChildPoisoningsby_Agedrop.drop(ChildPoisoningsby_Agedrop.index[0], inplace = True)
#ChildPoisoningsby_Agedrop

# %%
#ChildPoisoningsby_Yeardrop.drop(ChildPoisoningsby_Yeardrop.index[0], inplace = True)
#ChildPoisoningsby_Yeardrop.plot()

# %%
# Changed Row 1 to header for ChildPoisoningsby_Year
#FinalYeardf = ChildPoisoningsby_Yeardrop.rename(columns=ChildPoisoningsby_Yeardrop.iloc[0]).drop(ChildPoisoningsby_Yeardrop.index[0])
#FinalYeardf1 = FinalYeardf.rename(columns = header)

# %%
#FinalYeardf

# %%
#FinalYeardf.drop(FinalYeardf.index[1], inplace = True)

# %%
#FinalYeardf

# %%
# Changed Row 1 to header ChildPoisoningsby_Age
#FinalAgedf = ChildPoisoningsby_Agedrop.rename(columns=ChildPoisoningsby_Agedrop.iloc[0]).drop(ChildPoisoningsby_Agedrop.index[0])

# %%
#FinalAgedf.drop(FinalAgedf.index[1], inplace = True)

# %%
#FinalAgedf

# %%
# fix data types for your columns
#ChildPoisoningsby_Agedrop.columns.set_levels(ChildPoisoningsby_Agedrop.columns.levels[0].astype(str), level=0, inplace = True)
# Stack your data
#ChildPoisoningsby_Agedrop.stack(level=0)
#ChildPoisoningsby_Agedrop1 = ChildPoisoningsby_Age.dropna()
#ChildPoisoningsby_Agedrop1
# add age columns
# concat tables together to get master file
# save master file

# %%
# fix data types for your columns
#ChildPoisoningsby_Yeardrop.columns.set_levels(ChildPoisoningsby_Yeardrop.columns.levels[0].astype(str), level=0, inplace = True)
# Stack your data
#ChildPoisoningsby_Yeardrop.stack(level=0)
# add age columns
# concat tables together to get master file
# save master file

# %%
# fig, ax = plt.subplots()
# ax.plt(ChildPoisoningsby_Agedrop)/
# ax.plt(ChildPoisoningsby_Agedrop["Rate"])
# ax.set(xlabel="Age", ylabel="Rate", title="Age vs Rate")
#xlabel = "Count"
#ylabel = "Rate"
# ax.grid()
# plt.show()

# fig = plt.figure(figsize=(12,5))
# ax = plt.subplot()
# plt.plot(ChildPoisoningsby_Agedrop, color = 'green' )
# xlabel = "Rate"
# ylabel = "Age"
# ax.plt(ChildPoisoningsby_Agedrop.columns())
# ax.plt(ChildPoisoningsby_Agedrop["Rate"])
# ax.grid(True)
# plt.show()
# ChildPoisoningsby_Agedrop[["Age", "Rate"]].plot()

ChildPoisoningsby_Yeardrop

# %%
#FinalAgedf.drop(FinalAgedf.index[1], inplace = True)

# %%
#FinalYeardf.reset_index(inplace=True, drop=True)

# %%
#FinalYeardf

# %%
#FinalAgedf

# %%
# FinalYeardf.rename(columns={'Total for selection': 'Total Count', 'Total for selection': 'Total Rate'}, inplace=True)

# %%
# Changed Row 1 to header ChildPoisoningsby_Age
FinalAgedf = ChildPoisoningsby_Agedrop.rename(columns=ChildPoisoningsby_Agedrop.iloc[0]).drop(ChildPoisoningsby_Agedrop.index[0])

# %%
FinalAgedf.drop(FinalAgedf.index[1], inplace = True)

# %%
FinalAgedf.drop(FinalAgedf.index[0], axis=1)

# %%
FinalAgedf

# %%
# Merge our two data frames together
# combined_ChildPoisoning_data = pd.merge(ChildPoisoningsby_Age, ChildPoisoningsby_Year, on="Mechanism")
# combined_ChildPoisoning_data.head()

# %%
# Delete the duplicate 'Country Code' column and rename the first one back to 'Country Code'
# del combined_unemployed_data['Country Code_y']
# combined_unemployed_data = combined_unemployed_data.rename(columns={"Country Code_x":"Country Code"})
# combined_unemployed_data.head()

# %%
# Set the 'Country Code' to be our index for easy referencing of rows
combined_unemployed_data = combined_unemployed_data.set_index("Country Code")

# %%
# Collect the mean unemployment rates for the world
average_unemployment = combined_unemployed_data.mean()

# Collect the years where data was collected
years = average_unemployment.keys()

# %%
# Plot the world average as a line chart
world_avg, = plt.plot(years, average_unemployment, color="blue", label="World Average" )

# Plot the unemployment values for a single country
country_one, = plt.plot(years, combined_unemployed_data.loc['USA',["2010","2011","2012","2013","2014"]], 
                        color="green",label=combined_unemployed_data.loc['USA',"Country Name"])

# Create a legend for our chart
plt.legend(handles=[world_avg, country_one], loc="best")

# Show the chart
plt.show()

# %%
average_unemployment.plot(label="World Average")
combined_unemployed_data.loc['USA', "2010":"2014"].plot(label="United States")
plt.legend()
plt.show()

# %%
# %matplotlib notebook

# %%
# Import Dependencies
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Import our data into pandas from CSV
used_string = '../Resources/used_cars.csv'
used_car_df = pd.read_csv(used_string)

used_car_df

# %%
# Create a group based on the values in the 'maker' column
maker_group = used_car_df.groupby('maker')

# Count how many times each maker appears in our group
count_makers = maker_group['maker'].count()

count_makers

# %%
# Create a bar chart based off of the group series from before
count_chart = count_makers.plot(kind='bar')

# Set the xlabel and ylabel using class methods
count_chart.set_xlabel("Car Manufacturer")
count_chart.set_ylabel("Number of Cars")


plt.show()
plt.tight_layout()
