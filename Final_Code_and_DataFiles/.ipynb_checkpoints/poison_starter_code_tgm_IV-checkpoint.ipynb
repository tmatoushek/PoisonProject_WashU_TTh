# %%
# I finally got my code working. Here's my takeaways

# 1. Delete the first 3 lines of each data file to 
    #get rid of those merged cells.

# 2. Go ahead and rename those columns in Excel. 
    #As nice as it would be to do that in Python, 
    #it just seems to work better the other way.

# 3. Watch the data type of the column names 
    #and make sure they all are the same type before you stack.

# I also would recommend adding your age variable after the stack.

# %%
# # read in data
# MoPoisonData = pd.read_excel("ER_Poisonings_Ages_0-1_by_year.xlsx",
#                             header = [0,1], #skiprows = [0,1,2],
#                             na_values = "x", skipfooter = 6)

# # fix data types for your columns
# MoPoisonData.columns.set_levels(MoPoisonData.columns.levels[0].astype(str), level=0, inplace = True)

# # Stack your data
# MoPoisonData.stack(level=0)

# # add age columns

# # concat tables together to get master file

# # Reset Index

# # save master file

# %%
# Dependencies
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
# Read CSV

mo_geo_key = pd.read_excel("mo_geo_key.xlsx")

MoPsnDat_0_1 = pd.read_excel("ER_Poisonings_Ages_0-1_by_year_w_tfs.xlsx", 
                             header = [0,1], na_values = "x")

MoPsnDat_1_4 = pd.read_excel("ER_Poisonings_Ages_1-4_by_year_w_tfs.xlsx", 
                             header = [0,1], na_values = "x") 

MoPsnDat_5_9 = pd.read_excel("ER_Poisonings_Ages_5-9_by_year_w_tfs.xlsx", 
                             header = [0,1], na_values = "x")

MoPsnDat_10_14 = pd.read_excel("ER_Poisonings_Ages_10-14_by_year_w_tfs.xlsx", 
                             header = [0,1], na_values = "x") 

MoPsnDat_15_17 = pd.read_excel("ER_Poisonings_Ages_15-17_by_year_w_tfs.xlsx", 
                             header = [0,1], na_values = "x")


    
# # Merge our two data frames together
# combined_unemployed_data = pd.merge(unemployed_data_one, unemployed_data_two, on="Country Name")

# %%
# fix data types for your columns
#mo_geo_key.columns.set_levels(mo_geo_key.columns.levels[0].astype(str), level=0, inplace = True)

mo_geo_key.head()
# Out:
#      County BRFSS Region LPHA Region
# 0     Adair    Northeast           B
# 1    Andrew    Northwest           H
# 2  Atchison    Northwest           H
# 3   Audrain      Central           F
# 4     Barry    Southwest           D

# %%
# Stack your data
# Stk_mo_geo_key = mo_geo_key.stack(level=0)

# Stk_mo_geo_key.head()

# %%
# fix data types for your columns
MoPsnDat_0_1.columns.set_levels(MoPsnDat_0_1.columns.levels[0].astype(str), level=0, inplace = True)

MoPsnDat_0_1.head()
# Out:
# Year        2001             2002             2003             2004  ...   \
# Statistics Count Rate Notes Count Rate Notes Count Rate Notes Count  ...
# County                                                               ...
# Adair        NaN  NaN   NaN   NaN  NaN   NaN   NaN  NaN   NaN   NaN  ...
# Andrew       NaN  NaN   NaN   NaN  NaN   NaN   NaN  NaN   NaN   NaN  ...
# Atchison     NaN  NaN   NaN   NaN  NaN   NaN   NaN  NaN   NaN   NaN  ...
# Audrain      NaN  NaN   NaN   NaN  NaN   NaN   NaN  NaN   NaN   NaN  ...
# Barry        NaN  NaN   NaN   NaN  NaN   NaN   NaN  NaN   NaN   NaN  ...
#
# Year        2013  2014             2015            Total for selection        \
# Statistics Notes Count Rate Notes Count Rate Notes               Count  Rate
# County
# Adair        NaN   NaN  NaN   NaN   NaN  NaN   NaN                13.0  3.10
# Andrew       NaN   NaN  NaN   NaN   NaN  NaN   NaN                 6.0  2.16
# Atchison     NaN   NaN  NaN   NaN   NaN  NaN   NaN                 NaN   NaN
# Audrain      NaN   NaN  NaN   NaN   NaN  NaN   NaN                11.0  1.98
# Barry        NaN   NaN  NaN   NaN   NaN  NaN   NaN                27.0  3.80
#
# Year
# Statistics Notes
# County
# Adair          *
# Andrew         *
# Atchison     NaN
# Audrain        *
# Barry        NaN
#
# [5 rows x 48 columns]

# %%
# Stack your data
Stk_MoPsnDat_0_1 = MoPsnDat_0_1.stack(level=0)

#Insert age_group key for each data set
Stk_MoPsnDat_0_1.insert(0, 'age_grp', '0-1')

Stk_MoPsnDat_0_1.head()
# Out:
# Statistics                  age_grp  Count Notes  Rate
# County  Year
# Adair   Total for selection     0-1   13.0     *  3.10
# Andrew  Total for selection     0-1    6.0     *  2.16
# Audrain Total for selection     0-1   11.0     *  1.98
# Barry   Total for selection     0-1   27.0   NaN  3.80
# Barton  Total for selection     0-1   11.0     *  4.69

# %%
# fix data types for your columns
MoPsnDat_1_4.columns.set_levels(MoPsnDat_1_4.columns.levels[0].astype(str), level=0, inplace = True)

MoPsnDat_1_4.head()
# Out:
# Year        2001              2002              2003              2004  ...   \
# Statistics Count  Rate Notes Count  Rate Notes Count  Rate Notes Count  ...
# County                                                                  ...
# Adair        NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# Andrew       NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# Atchison     NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# Audrain     11.0  8.51     *   8.0  6.42     *   7.0  5.79     *   9.0  ...
# Barry       16.0  8.75     *  11.0  6.10     *  18.0  9.56     *  26.0  ...
#
# Year        2013  2014              2015             Total for selection  \
# Statistics Notes Count  Rate Notes Count  Rate Notes               Count
# County
# Adair        NaN   NaN   NaN   NaN   NaN   NaN   NaN                 152
# Andrew       NaN   NaN   NaN   NaN   NaN   NaN   NaN                  48
# Atchison     NaN   NaN   NaN   NaN   NaN   NaN   NaN                  29
# Audrain        *  11.0  8.93     *  11.0  8.80     *                 180
# Barry          *  13.0  6.96     *  15.0  8.43     *                 288
#
# Year
# Statistics   Rate Notes
# County
# Adair        9.75   NaN
# Andrew       4.19   NaN
# Atchison     7.73   NaN
# Audrain      9.10   NaN
# Barry       10.33   NaN
#
# [5 rows x 48 columns]

# %%
# Stack your data
Stk_MoPsnDat_1_4 = MoPsnDat_1_4.stack(level=0)

#Insert age_group key for each data set
Stk_MoPsnDat_1_4.insert(0, 'age_grp', '1-4')

Stk_MoPsnDat_1_4.head()
# Out:
# Statistics                   age_grp  Count Notes  Rate
# County   Year
# Adair    Total for selection     1-4  152.0   NaN  9.75
# Andrew   Total for selection     1-4   48.0   NaN  4.19
# Atchison Total for selection     1-4   29.0   NaN  7.73
# Audrain  2001                    1-4   11.0     *  8.51
#          2002                    1-4    8.0     *  6.42

# %%
# fix data types for your columns
MoPsnDat_5_9.columns.set_levels(MoPsnDat_5_9.columns.levels[0].astype(str), level=0, inplace = True)

MoPsnDat_5_9.head()
# Out:
# Year        2001             2002             2003             2004  ...   \
# Statistics Count Rate Notes Count Rate Notes Count Rate Notes Count  ...
# County                                                               ...
# Adair        NaN  NaN   NaN   NaN  NaN   NaN   NaN  NaN   NaN   NaN  ...
# Andrew       NaN  NaN   NaN   NaN  NaN   NaN   NaN  NaN   NaN   NaN  ...
# Atchison     NaN  NaN   NaN   NaN  NaN   NaN   NaN  NaN   NaN   NaN  ...
# Audrain      NaN  NaN   NaN   NaN  NaN   NaN   NaN  NaN   NaN   NaN  ...
# Barry        NaN  NaN   NaN   NaN  NaN   NaN   NaN  NaN   NaN   NaN  ...
#
# Year        2013  2014             2015            Total for selection        \
# Statistics Notes Count Rate Notes Count Rate Notes               Count  Rate
# County
# Adair        NaN   NaN  NaN   NaN   NaN  NaN   NaN                49.0  2.45
# Andrew       NaN   NaN  NaN   NaN   NaN  NaN   NaN                14.0  0.82
# Atchison     NaN   NaN  NaN   NaN   NaN  NaN   NaN                13.0  2.69
# Audrain      NaN   NaN  NaN   NaN   NaN  NaN   NaN                59.0  2.37
# Barry        NaN   NaN  NaN   NaN   NaN  NaN   NaN               107.0  3.06
#
# Year
# Statistics Notes
# County
# Adair        NaN
# Andrew         *
# Atchison       *
# Audrain      NaN
# Barry        NaN
#
# [5 rows x 48 columns]

# %%
# Stack your data
Stk_MoPsnDat_5_9 = MoPsnDat_5_9.stack(level=0)

#Insert age_group key for each data set
Stk_MoPsnDat_5_9.insert(0, 'age_grp', '5-9')

Stk_MoPsnDat_5_9.head()
# Out:
# Statistics                   age_grp  Count Notes  Rate
# County   Year
# Adair    Total for selection     5-9   49.0   NaN  2.45
# Andrew   Total for selection     5-9   14.0     *  0.82
# Atchison Total for selection     5-9   13.0     *  2.69
# Audrain  Total for selection     5-9   59.0   NaN  2.37
# Barry    Total for selection     5-9  107.0   NaN  3.06

# %%
# fix data types for your columns
MoPsnDat_10_14.columns.set_levels(MoPsnDat_10_14.columns.levels[0].astype(str), level=0, inplace = True)

MoPsnDat_10_14.head()
# Out:
# Year        2001              2002              2003              2004  ...   \
# Statistics Count  Rate Notes Count  Rate Notes Count  Rate Notes Count  ...
# County                                                                  ...
# Adair        NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# Andrew       NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# Atchison     NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# Audrain      NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# Barry        6.0  2.36     *   7.0  2.71     *   5.0  1.87     *  13.0  ...
#
# Year        2013  2014              2015             Total for selection  \
# Statistics Notes Count  Rate Notes Count  Rate Notes               Count
# County
# Adair        NaN   NaN   NaN   NaN   NaN   NaN   NaN                47.0
# Andrew       NaN   NaN   NaN   NaN   NaN   NaN   NaN                16.0
# Atchison     NaN   NaN   NaN   NaN   NaN   NaN   NaN                20.0
# Audrain      NaN   NaN   NaN   NaN   NaN   NaN   NaN                67.0
# Barry          *   7.0  3.08     *  14.0  6.22     *               133.0
#
# Year
# Statistics  Rate Notes
# County
# Adair       2.38   NaN
# Andrew      0.84     *
# Atchison    3.62   NaN
# Audrain     2.54   NaN
# Barry       3.51   NaN
#
# [5 rows x 48 columns]

# %%
# Stack your data
Stk_MoPsnDat_10_14 = MoPsnDat_10_14.stack(level=0)

#Insert age_group key for each data set
Stk_MoPsnDat_10_14.insert(0, 'age_grp', '10-14')

Stk_MoPsnDat_10_14.head()
# Out:
# Statistics                   age_grp  Count Notes  Rate
# County   Year
# Adair    Total for selection   10-14   47.0   NaN  2.38
# Andrew   Total for selection   10-14   16.0     *  0.84
# Atchison Total for selection   10-14   20.0   NaN  3.62
# Audrain  Total for selection   10-14   67.0   NaN  2.54
# Barry    2001                  10-14    6.0     *  2.36

# %%
# fix data types for your columns
MoPsnDat_15_17.columns.set_levels(MoPsnDat_15_17.columns.levels[0].astype(str), level=0, inplace = True)

#MoPsnDat_15_17['Year'].astype(int)
#MoPsnDat_15_17.Year = pd.to_numeric(MoPsnDat_15_17.Year, errors='coerce')

MoPsnDat_0_1.head()
# Out:
# Year        2001             2002             2003             2004  ...   \
# Statistics Count Rate Notes Count Rate Notes Count Rate Notes Count  ...
# County                                                               ...
# Adair        NaN  NaN   NaN   NaN  NaN   NaN   NaN  NaN   NaN   NaN  ...
# Andrew       NaN  NaN   NaN   NaN  NaN   NaN   NaN  NaN   NaN   NaN  ...
# Atchison     NaN  NaN   NaN   NaN  NaN   NaN   NaN  NaN   NaN   NaN  ...
# Audrain      NaN  NaN   NaN   NaN  NaN   NaN   NaN  NaN   NaN   NaN  ...
# Barry        NaN  NaN   NaN   NaN  NaN   NaN   NaN  NaN   NaN   NaN  ...
#
# Year        2013  2014             2015            Total for selection        \
# Statistics Notes Count Rate Notes Count Rate Notes               Count  Rate
# County
# Adair        NaN   NaN  NaN   NaN   NaN  NaN   NaN                13.0  3.10
# Andrew       NaN   NaN  NaN   NaN   NaN  NaN   NaN                 6.0  2.16
# Atchison     NaN   NaN  NaN   NaN   NaN  NaN   NaN                 NaN   NaN
# Audrain      NaN   NaN  NaN   NaN   NaN  NaN   NaN                11.0  1.98
# Barry        NaN   NaN  NaN   NaN   NaN  NaN   NaN                27.0  3.80
#
# Year
# Statistics Notes
# County
# Adair          *
# Andrew         *
# Atchison     NaN
# Audrain        *
# Barry        NaN
#
# [5 rows x 48 columns]

# %%
# Stack your data
Stk_MoPsnDat_15_17 = MoPsnDat_15_17.stack(level=0)

#Insert age_group key for each data set
Stk_MoPsnDat_15_17.insert(0, 'age_grp', '15-17')

Stk_MoPsnDat_15_17.head()
# Out:
# Statistics                   age_grp  Count Notes  Rate
# County   Year
# Adair    Total for selection   15-17   50.0   NaN  3.99
# Andrew   Total for selection   15-17   26.0   NaN  2.23
# Atchison Total for selection   15-17   27.0   NaN  6.68
# Audrain  Total for selection   15-17   81.0   NaN  4.59
# Barry    Total for selection   15-17  117.0   NaN  5.08

# %%
#mo_geo_key, Stk_mo_geo_key,
Stk_mopoisframes = [Stk_MoPsnDat_0_1, Stk_MoPsnDat_1_4, Stk_MoPsnDat_5_9, Stk_MoPsnDat_10_14, Stk_MoPsnDat_15_17]
Stk_mopois_mstr_dframe = pd.concat(Stk_mopoisframes)

Stk_mopois_mstr_dframe.reset_index(inplace = True)
#stacked.loc[(stacked.County != 'Total for Selection') & (stacked.Year != 'Total for Selection')]
Stk_mopois_mstr_dframe.loc[(Stk_mopois_mstr_dframe.County != 'Total for selection') & 
                           (Stk_mopois_mstr_dframe.Year != 'Total for selection')]
# Out:
# Statistics    County  Year age_grp   Count Notes  Rate
# 20             Clark  2001     0-1     0.0   NaN  0.00
# 21             Clark  2002     0-1     0.0   NaN  0.00
# 22             Clark  2003     0-1     0.0   NaN  0.00
# 23             Clark  2004     0-1     0.0   NaN  0.00
# 24             Clark  2005     0-1     0.0   NaN  0.00
# 25             Clark  2006     0-1     0.0   NaN  0.00
# 26             Clark  2007     0-1     0.0   NaN  0.00
# 27             Clark  2008     0-1     0.0   NaN  0.00
# 28             Clark  2009     0-1     0.0   NaN  0.00
# 29             Clark  2010     0-1     0.0   NaN  0.00
# 30             Clark  2011     0-1     0.0   NaN  0.00
# 31             Clark  2012     0-1     0.0   NaN  0.00
# 32             Clark  2013     0-1     0.0   NaN  0.00
# 33             Clark  2014     0-1     0.0   NaN  0.00
# 34             Clark  2015     0-1     0.0   NaN  0.00
# 35             Clark  2001     0-1     0.0   NaN  0.00
# 36             Clark  2002     0-1     0.0   NaN  0.00
# 37             Clark  2003     0-1     0.0   NaN  0.00
# 38             Clark  2004     0-1     0.0   NaN  0.00
# 39             Clark  2005     0-1     0.0   NaN  0.00
# 40             Clark  2006     0-1     0.0   NaN  0.00
# 41             Clark  2007     0-1     0.0   NaN  0.00
# 42             Clark  2008     0-1     0.0   NaN  0.00
# 43             Clark  2009     0-1     0.0   NaN  0.00
# 44             Clark  2010     0-1     0.0   NaN  0.00
# 45             Clark  2011     0-1     0.0   NaN  0.00
# 46             Clark  2012     0-1     0.0   NaN  0.00
# 47             Clark  2013     0-1     0.0   NaN  0.00
# 48             Clark  2014     0-1     0.0   NaN  0.00
# 49             Clark  2015     0-1     0.0   NaN  0.00
# ...              ...   ...     ...     ...   ...   ...
# 4122        Missouri  2001   15-17  1004.0   NaN  4.02
# 4123        Missouri  2002   15-17  1061.0   NaN  4.24
# 4124        Missouri  2003   15-17  1073.0   NaN  4.30
# 4125        Missouri  2004   15-17  1039.0   NaN  4.15
# 4126        Missouri  2005   15-17  1026.0   NaN  4.02
# 4127        Missouri  2006   15-17  1050.0   NaN  4.05
# 4128        Missouri  2007   15-17  1000.0   NaN  3.85
# 4129        Missouri  2008   15-17  1042.0   NaN  4.08
# 4130        Missouri  2009   15-17   938.0   NaN  3.73
# 4131        Missouri  2010   15-17   942.0   NaN  3.80
# 4132        Missouri  2011   15-17   917.0   NaN  3.78
# 4133        Missouri  2012   15-17   862.0   NaN  3.61
# 4134        Missouri  2013   15-17   932.0   NaN  3.94
# 4135        Missouri  2014   15-17   960.0   NaN  4.05
# 4136        Missouri  2015   15-17  1105.0   NaN  4.61
# 4137        Missouri  2001   15-17  1004.0   NaN  4.02
# 4138        Missouri  2002   15-17  1061.0   NaN  4.24
# 4139        Missouri  2003   15-17  1073.0   NaN  4.30
# 4140        Missouri  2004   15-17  1039.0   NaN  4.15
# 4141        Missouri  2005   15-17  1026.0   NaN  4.02
# 4142        Missouri  2006   15-17  1050.0   NaN  4.05
# 4143        Missouri  2007   15-17  1000.0   NaN  3.85
# 4144        Missouri  2008   15-17  1042.0   NaN  4.08
# 4145        Missouri  2009   15-17   938.0   NaN  3.73
# 4146        Missouri  2010   15-17   942.0   NaN  3.80
# 4147        Missouri  2011   15-17   917.0   NaN  3.78
# 4148        Missouri  2012   15-17   862.0   NaN  3.61
# 4149        Missouri  2013   15-17   932.0   NaN  3.94
# 4150        Missouri  2014   15-17   960.0   NaN  4.05
# 4151        Missouri  2015   15-17  1105.0   NaN  4.61
#
# [3450 rows x 6 columns]

# %%
Stk_mopois_mstr_dframe.reset_index()

#mopois_stkd_mstr_dframe.head
Stk_mopois_mstr_dframe.head()
# Out:
# Statistics   County                 Year age_grp  Count Notes  Rate
# 0             Adair  Total for selection     0-1   13.0     *  3.10
# 1            Andrew  Total for selection     0-1    6.0     *  2.16
# 2           Audrain  Total for selection     0-1   11.0     *  1.98
# 3             Barry  Total for selection     0-1   27.0   NaN  3.80
# 4            Barton  Total for selection     0-1   11.0     *  4.69

# %%
#MoPsnDat_0_1.set_index(['age_grp'])
#MoPsnDat_0_1.set_index(['County'])
#mopois_stkd_mstr_dframe.set_index(['age_grp', 'County'],drop=False)

Stk_mopois_mstr_dframe.reset_index()

#MoPsnDat_0_1.head()

#MoPsnDat_0_1.info()
# Out:
# Statistics          County                 Year age_grp    Count Notes  Rate
# 0                    Adair  Total for selection     0-1     13.0     *  3.10
# 1                   Andrew  Total for selection     0-1      6.0     *  2.16
# 2                  Audrain  Total for selection     0-1     11.0     *  1.98
# 3                    Barry  Total for selection     0-1     27.0   NaN  3.80
# 4                   Barton  Total for selection     0-1     11.0     *  4.69
# 5                    Bates  Total for selection     0-1     18.0     *  5.84
# 6                   Benton  Total for selection     0-1      6.0     *  2.47
# 7                Bollinger  Total for selection     0-1     11.0     *  5.13
# 8                    Boone  Total for selection     0-1     51.0   NaN  1.68
# 9                 Buchanan  Total for selection     0-1     82.0   NaN  4.55
# 10                  Butler  Total for selection     0-1     53.0   NaN  6.23
# 11                Caldwell  Total for selection     0-1      7.0     *  4.29
# 12                Callaway  Total for selection     0-1     28.0   NaN  3.67
# 13                  Camden  Total for selection     0-1     34.0   NaN  5.51
# 14          Cape Girardeau  Total for selection     0-1     41.0   NaN  2.98
# 15                  Carter  Total for selection     0-1      5.0     *  4.19
# 16                    Cass  Total for selection     0-1     43.0   NaN  2.35
# 17                   Cedar  Total for selection     0-1     14.0     *  5.68
# 18                Chariton  Total for selection     0-1      5.0     *  3.83
# 19               Christian  Total for selection     0-1     35.0   NaN  2.36
# 20                   Clark                 2001     0-1      0.0   NaN  0.00
# 21                   Clark                 2002     0-1      0.0   NaN  0.00
# 22                   Clark                 2003     0-1      0.0   NaN  0.00
# 23                   Clark                 2004     0-1      0.0   NaN  0.00
# 24                   Clark                 2005     0-1      0.0   NaN  0.00
# 25                   Clark                 2006     0-1      0.0   NaN  0.00
# 26                   Clark                 2007     0-1      0.0   NaN  0.00
# 27                   Clark                 2008     0-1      0.0   NaN  0.00
# 28                   Clark                 2009     0-1      0.0   NaN  0.00
# 29                   Clark                 2010     0-1      0.0   NaN  0.00
# ...                    ...                  ...     ...      ...   ...   ...
# 4123              Missouri                 2002   15-17   1061.0   NaN  4.24
# 4124              Missouri                 2003   15-17   1073.0   NaN  4.30
# 4125              Missouri                 2004   15-17   1039.0   NaN  4.15
# 4126              Missouri                 2005   15-17   1026.0   NaN  4.02
# 4127              Missouri                 2006   15-17   1050.0   NaN  4.05
# 4128              Missouri                 2007   15-17   1000.0   NaN  3.85
# 4129              Missouri                 2008   15-17   1042.0   NaN  4.08
# 4130              Missouri                 2009   15-17    938.0   NaN  3.73
# 4131              Missouri                 2010   15-17    942.0   NaN  3.80
# 4132              Missouri                 2011   15-17    917.0   NaN  3.78
# 4133              Missouri                 2012   15-17    862.0   NaN  3.61
# 4134              Missouri                 2013   15-17    932.0   NaN  3.94
# 4135              Missouri                 2014   15-17    960.0   NaN  4.05
# 4136              Missouri                 2015   15-17   1105.0   NaN  4.61
# 4137              Missouri                 2001   15-17   1004.0   NaN  4.02
# 4138              Missouri                 2002   15-17   1061.0   NaN  4.24
# 4139              Missouri                 2003   15-17   1073.0   NaN  4.30
# 4140              Missouri                 2004   15-17   1039.0   NaN  4.15
# 4141              Missouri                 2005   15-17   1026.0   NaN  4.02
# 4142              Missouri                 2006   15-17   1050.0   NaN  4.05
# 4143              Missouri                 2007   15-17   1000.0   NaN  3.85
# 4144              Missouri                 2008   15-17   1042.0   NaN  4.08
# 4145              Missouri                 2009   15-17    938.0   NaN  3.73
# 4146              Missouri                 2010   15-17    942.0   NaN  3.80
# 4147              Missouri                 2011   15-17    917.0   NaN  3.78
# 4148              Missouri                 2012   15-17    862.0   NaN  3.61
# 4149              Missouri                 2013   15-17    932.0   NaN  3.94
# 4150              Missouri                 2014   15-17    960.0   NaN  4.05
# 4151              Missouri                 2015   15-17   1105.0   NaN  4.61
# 4152              Missouri  Total for selection   15-17  14951.0   NaN  4.01
#
# [4153 rows x 6 columns]

# %%
#Change 'Year' data type
#df.b = pd.to_numeric(df['b'], errors='coerce')
#Stk_mopois_mstr_dframe.to_numeric(Year)
#df['C'] = df['C'].apply(np.int64)
#tk_mopois_mstr_dframe['Year'] = Stk_mopois_mstr_dframe['Year'].apply(np.int64)
#Stk_mopois_mstr_dframe.Year = pd.to_numeric(Stk_mopois_mstr_dframe.Year, errors='coerce')


#output_data_file = "Temp_output/cities.csv"
#Stk_mopois_mstr_dframe.to_csv("Stk_mopois_mstr_dframe.csv", index=False)

# %%
#pandas.pivot_table(data, values=None, index=None, columns=None, aggfunc='mean', fill_value=None, margins=False, dropna=True, margins_name='All')
Pvt_Stk_mopois_mstr_dframe = Stk_mopois_mstr_dframe.pivot_table(index = 'Year', columns = 'age_grp', values = 'Rate')
Pvt_Stk_mopois_mstr_dframe.head()
# Out:
# age_grp      0-1       1-4   10-14     15-17       5-9
# Year
# 2001     2.46625  9.028462  2.3285  4.723684  2.368571
# 2002     2.22125  9.249615  2.5310  4.297895  2.521429
# 2003     2.00250  9.511923  2.3660  4.406842  2.319524
# 2004     2.17000  9.936346  2.6335  4.342105  2.833810
# 2005     1.90875  9.727692  2.4160  4.176316  2.316190

# %%
#Pvt_Stk_mopois_mstr_dframe.plot(x = 'Year', y = 'Rate')
Pvt_Stk_mopois_mstr_dframe.plot()
#plt.xticks([2002, 2004, 2006, 2008, 2010, 2012, 2014])
plt.title("ER Poisoning Rates per Age Group")
plt.legend(loc='best')
plt.ylabel('Rate/1000')
# Save the figure
plt.savefig("ER Poisoning Rates per Age Group.png")

# %%
#pandas.pivot_table(data, values=None, index=None, columns=None, aggfunc='mean', fill_value=None, margins=False, dropna=True, margins_name='All')
Pvt_Stk_mopois_mstr_dframe = Stk_mopois_mstr_dframe.pivot_table(index = 'Year', columns = 'age_grp', values = 'Total for selection')

# %%
#Pvt_Stk_mopois_mstr_dframe.plot(x = 'Year', y = 'Rate')
Pvt_Stk_mopois_mstr_dframe.plot()
#plt.xticks([2002, 2004, 2006, 2008, 2010, 2012, 2014])
plt.title("ER Poisoning Rates per Age Group")
plt.legend(loc='best')
plt.ylabel('Rate/1000')
# Save the figure
plt.savefig("ER Poisoning Rates per Age Group.png")

# %%
## EVERYTHING below this is 'boneyard' code from the starter file...

# %%
# Set the 'Country Code' to be our index for easy referencing of rows
#combined_unemployed_data = combined_unemployed_data.set_index("Country Code")

# %%
# Collect the mean unemployment rates for the world
#average_unemployment = combined_unemployed_data.mean()

# Collect the years where data was collected
#years = average_unemployment.keys()

# %%
# Plot the world average as a line chart
world_avg, = plt.plot(years, average_unemployment, color="blue", label="World Average" )

# Plot the unemployment values for a single country
country_one, = plt.plot(years, combined_unemployed_data.loc['USA',["2010","2011","2012","2013","2014"]], 
                        color="green",label=combined_unemployed_data.loc['USA',"Country Name"])

# Create a legend for our chart
plt.legend(handles=[world_avg, country_one], loc="best")

# Show the chart
plt.show()

# %%
average_unemployment.plot(label="World Average")
combined_unemployed_data.loc['USA', "2010":"2014"].plot(label="United States")
plt.legend()
plt.show()

# %%
# %matplotlib notebook

# %%
# Import Dependencies
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Import our data into pandas from CSV
used_string = '../Resources/used_cars.csv'
used_car_df = pd.read_csv(used_string)

used_car_df

# %%
# Create a group based on the values in the 'maker' column
maker_group = used_car_df.groupby('maker')

# Count how many times each maker appears in our group
count_makers = maker_group['maker'].count()

count_makers

# %%
# Create a bar chart based off of the group series from before
count_chart = count_makers.plot(kind='bar')

# Set the xlabel and ylabel using class methods
count_chart.set_xlabel("Car Manufacturer")
count_chart.set_ylabel("Number of Cars")


plt.show()
plt.tight_layout()
