# %%
# Dependencies
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
# Read CSV

ChildPoisoningsby_Age = pd.read_csv("Resources/ChildPoisoningsbyType_Age.csv")
ChildPoisoningsby_Year = pd.read_csv("Resources/ChildPoisoningsbyType_Year.csv")

ChildPoisoningsby_Age
# Out:
#                                                Title:  \
# 0   Data selected in addition to rows and columns ...
# 1                                                Age:
# 2                                         Statistics:
# 3                                           Mechanism
# 4                          Poison/Overdose: All Other
# 5                      Poison/Overdose: Drugs/Alcohol
# 6         Poison/Overdose: Gas/Cleaners/Caustics/etc.
# 7                                 Total for selection
# 8                                               Rate:
# 9                                             Source:
# 10                                      Generated On:
#
#                            Missouri Resident Injuries Unnamed: 2 Unnamed: 3  \
# 0   Single Year(s): 2015 2014 2013 2012 2011 2010 ...        NaN        NaN
# 1                                             Under 1    Under 1     '1 - 4
# 2                                               Count       Rate      Count
# 3                                                 NaN        NaN        NaN
# 4                                                   0          0          0
# 5                                                1481     127.64      19655
# 6                                                1125      96.96       7298
# 7                                                2606      224.6      26953
# 8                               Crude Rate per 100000        NaN        NaN
# 9                        DHSS - MOPHIMS - Injury MICA        NaN        NaN
# 10                                     8/11/2018 6:25        NaN        NaN
#
#    Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8  \
# 0         NaN        NaN        NaN        NaN        NaN
# 1      '1 - 4     '5 - 9     '5 - 9   '10 - 14   '10 - 14
# 2        Rate      Count       Rate      Count       Rate
# 3         NaN        NaN        NaN        NaN        NaN
# 4           0          0          0          0          0
# 5      433.44       2396      41.36       6425     106.25
# 6      160.94       1252      21.61       1324      21.89
# 7      594.38       3648      62.98       7749     128.14
# 8         NaN        NaN        NaN        NaN        NaN
# 9         NaN        NaN        NaN        NaN        NaN
# 10        NaN        NaN        NaN        NaN        NaN
#
#              Unnamed: 9          Unnamed: 10
# 0                   NaN                  NaN
# 1   Total for selection  Total for selection
# 2                 Count                 Rate
# 3                   NaN                  NaN
# 4                     0                    0
# 5                 29957               170.84
# 6                 10999                62.73
# 7                 40956               233.57
# 8                   NaN                  NaN
# 9                   NaN                  NaN
# 10                  NaN                  NaN

# %%
ChildPoisoningsby_Year
# Out:
#                                                Title:  \
# 0   Data selected in addition to rows and columns ...
# 1                                               Year:
# 2                                         Statistics:
# 3                                           Mechanism
# 4                          Poison/Overdose: All Other
# 5                      Poison/Overdose: Drugs/Alcohol
# 6         Poison/Overdose: Gas/Cleaners/Caustics/etc.
# 7                                 Total for selection
# 8                                               Rate:
# 9                                             Source:
# 10                                      Generated On:
#
#                            Missouri Resident Injuries Unnamed: 2 Unnamed: 3  \
# 0                  Age: Under 1 1 - 4 5 - 9 10 - 14;         NaN        NaN
# 1                                                2001       2001       2002
# 2                                               Count       Rate      Count
# 3                                                 NaN        NaN        NaN
# 4                                                   0          0          0
# 5                                                1914     162.65       2040
# 6                                                 936      79.54        915
# 7                                                2850     242.19       2955
# 8   Injury rates are annualized per 100000 residents.        NaN        NaN
# 9                        DHSS - MOPHIMS - Injury MICA        NaN        NaN
# 10                                     8/11/2018 6:06        NaN        NaN
#
#    Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  \
# 0         NaN        NaN        NaN        NaN        NaN        NaN
# 1        2002       2003       2003       2004       2004       2005
# 2        Rate      Count       Rate      Count       Rate      Count
# 3         NaN        NaN        NaN        NaN        NaN        NaN
# 4           0          0          0          0          0          0
# 5      173.71       1944     165.85       2001     170.96       2112
# 6       77.92        824       70.3        778      66.47        851
# 7      251.63       2768     236.15       2779     237.43       2963
# 8         NaN        NaN        NaN        NaN        NaN        NaN
# 9         NaN        NaN        NaN        NaN        NaN        NaN
# 10        NaN        NaN        NaN        NaN        NaN        NaN
#
#            ...          Unnamed: 23 Unnamed: 24 Unnamed: 25 Unnamed: 26  \
# 0          ...                  NaN         NaN         NaN         NaN
# 1          ...                 2012        2012        2013        2013
# 2          ...                Count        Rate       Count        Rate
# 3          ...                  NaN         NaN         NaN         NaN
# 4          ...                    0           0           0           0
# 5          ...                 2157         185        1843      158.77
# 6          ...                  717       61.49         694       59.79
# 7          ...                 2874      246.49        2537      218.55
# 8          ...                  NaN         NaN         NaN         NaN
# 9          ...                  NaN         NaN         NaN         NaN
# 10         ...                  NaN         NaN         NaN         NaN
#
#    Unnamed: 27 Unnamed: 28 Unnamed: 29 Unnamed: 30          Unnamed: 31  \
# 0          NaN         NaN         NaN         NaN                  NaN
# 1         2014        2014        2015        2015  Total for selection
# 2        Count        Rate       Count        Rate                Count
# 3          NaN         NaN         NaN         NaN                  NaN
# 4            0           0           0           0                    0
# 5         1608      139.14        1166      101.24                29957
# 6          583       50.45         466       40.46                10999
# 7         2191      189.58        1632      141.71                40956
# 8          NaN         NaN         NaN         NaN                  NaN
# 9          NaN         NaN         NaN         NaN                  NaN
# 10         NaN         NaN         NaN         NaN                  NaN
#
#             Unnamed: 32
# 0                   NaN
# 1   Total for selection
# 2                  Rate
# 3                   NaN
# 4                     0
# 5                170.84
# 6                 62.73
# 7                233.57
# 8                   NaN
# 9                   NaN
# 10                  NaN
#
# [11 rows x 33 columns]

# %%
#dfChildPoisoningsby_Age = pd.DataFrame(ChildPoisoningsby_Age)
#dfChildPoisoningsby_Year = pd.DataFrame(ChildPoisoningsby_Year)

# %%
ChildPoisoningsby_Agedrop = ChildPoisoningsby_Age.dropna()
ChildPoisoningsby_Agedrop
# Out:
#                                         Title: Missouri Resident Injuries  \
# 1                                         Age:                    Under 1
# 2                                  Statistics:                      Count
# 4                   Poison/Overdose: All Other                          0
# 5               Poison/Overdose: Drugs/Alcohol                       1481
# 6  Poison/Overdose: Gas/Cleaners/Caustics/etc.                       1125
# 7                          Total for selection                       2606
#
#   Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7  \
# 1    Under 1     '1 - 4     '1 - 4     '5 - 9     '5 - 9   '10 - 14
# 2       Rate      Count       Rate      Count       Rate      Count
# 4          0          0          0          0          0          0
# 5     127.64      19655     433.44       2396      41.36       6425
# 6      96.96       7298     160.94       1252      21.61       1324
# 7      224.6      26953     594.38       3648      62.98       7749
#
#   Unnamed: 8           Unnamed: 9          Unnamed: 10
# 1   '10 - 14  Total for selection  Total for selection
# 2       Rate                Count                 Rate
# 4          0                    0                    0
# 5     106.25                29957               170.84
# 6      21.89                10999                62.73
# 7     128.14                40956               233.57

# %%
ChildPoisoningsby_Yeardrop = ChildPoisoningsby_Year.dropna()
ChildPoisoningsby_Yeardrop
# Out:
#                                         Title: Missouri Resident Injuries  \
# 1                                        Year:                       2001
# 2                                  Statistics:                      Count
# 4                   Poison/Overdose: All Other                          0
# 5               Poison/Overdose: Drugs/Alcohol                       1914
# 6  Poison/Overdose: Gas/Cleaners/Caustics/etc.                        936
# 7                          Total for selection                       2850
#
#   Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7  \
# 1       2001       2002       2002       2003       2003       2004
# 2       Rate      Count       Rate      Count       Rate      Count
# 4          0          0          0          0          0          0
# 5     162.65       2040     173.71       1944     165.85       2001
# 6      79.54        915      77.92        824       70.3        778
# 7     242.19       2955     251.63       2768     236.15       2779
#
#   Unnamed: 8 Unnamed: 9         ...          Unnamed: 23 Unnamed: 24  \
# 1       2004       2005         ...                 2012        2012
# 2       Rate      Count         ...                Count        Rate
# 4          0          0         ...                    0           0
# 5     170.96       2112         ...                 2157         185
# 6      66.47        851         ...                  717       61.49
# 7     237.43       2963         ...                 2874      246.49
#
#   Unnamed: 25 Unnamed: 26 Unnamed: 27 Unnamed: 28 Unnamed: 29 Unnamed: 30  \
# 1        2013        2013        2014        2014        2015        2015
# 2       Count        Rate       Count        Rate       Count        Rate
# 4           0           0           0           0           0           0
# 5        1843      158.77        1608      139.14        1166      101.24
# 6         694       59.79         583       50.45         466       40.46
# 7        2537      218.55        2191      189.58        1632      141.71
#
#            Unnamed: 31          Unnamed: 32
# 1  Total for selection  Total for selection
# 2                Count                 Rate
# 4                    0                    0
# 5                29957               170.84
# 6                10999                62.73
# 7                40956               233.57
#
# [6 rows x 33 columns]

# %%
# Changed Row 1 to header for ChildPoisoningsby_Year
FinalYeardf = ChildPoisoningsby_Yeardrop.rename(columns=ChildPoisoningsby_Yeardrop.iloc[0]).drop(ChildPoisoningsby_Yeardrop.index[0])

# %%
FinalYeardf.drop(FinalYeardf.index[1], inplace = True)

# %%
# Changed Row 1 to header ChildPoisoningsby_Age
FinalAgedf = ChildPoisoningsby_Agedrop.rename(columns=ChildPoisoningsby_Agedrop.iloc[0]).drop(ChildPoisoningsby_Agedrop.index[0])

# %%
FinalAgedf.drop(FinalAgedf.index[1], inplace = True)

# %%
FinalYeardf
# Out:
#                                          Year:   2001    2001   2002    2002  \
# 2                                  Statistics:  Count    Rate  Count    Rate
# 5               Poison/Overdose: Drugs/Alcohol   1914  162.65   2040  173.71
# 6  Poison/Overdose: Gas/Cleaners/Caustics/etc.    936   79.54    915   77.92
# 7                          Total for selection   2850  242.19   2955  251.63
#
#     2003    2003   2004    2004   2005         ...           2012    2012  \
# 2  Count    Rate  Count    Rate  Count         ...          Count    Rate
# 5   1944  165.85   2001  170.96   2112         ...           2157     185
# 6    824    70.3    778   66.47    851         ...            717   61.49
# 7   2768  236.15   2779  237.43   2963         ...           2874  246.49
#
#     2013    2013   2014    2014   2015    2015 Total for selection  \
# 2  Count    Rate  Count    Rate  Count    Rate               Count
# 5   1843  158.77   1608  139.14   1166  101.24               29957
# 6    694   59.79    583   50.45    466   40.46               10999
# 7   2537  218.55   2191  189.58   1632  141.71               40956
#
#   Total for selection
# 2                Rate
# 5              170.84
# 6               62.73
# 7              233.57
#
# [4 rows x 33 columns]

# %%
#FinalYeardf = pd.read_excel('problem.xlsx', sheetname='WEEKLY NUMBERS', header=[0, 1])
#FinalYeardf.columns = FinalYeardf.columns.map('Year'.iloc,'Statistics'.iloc)
#header = FinalYeardf.iloc[1]
#FinalYeardf = FinalYeardf[0:]
#FinalYeardf.rename(columns = header)

#FinalYeardf1 = pd.FinalYeardf({'Year':[2001,2001,2002,2002,2003,2003,2004,2004,2005,2006,2006,2007,2007,2008,2008,2009,2009,2010,2010,2011,2011,2012,2012,2013,2013,2014,2014,2015,2015,Total for selection,Total for selection], 
#                             'Statistics:':[Count,Rate,Count,Rate,Count,Rate,Count,Rate,Count,Rate,Count,Rate,Count,Rate,Count,Rate,Count,Rate,Count,Rate,Count,Rate,Count,Rate,Count,Rate,Count,Rate,Count,Rate,Count,Rate]
#                              .set_index(['Year','Year'])

# %%
#FinalYeardf
FinalYeardf
# Out:
#                                          Year:   2001    2001   2002    2002  \
# 2                                  Statistics:  Count    Rate  Count    Rate
# 5               Poison/Overdose: Drugs/Alcohol   1914  162.65   2040  173.71
# 6  Poison/Overdose: Gas/Cleaners/Caustics/etc.    936   79.54    915   77.92
# 7                          Total for selection   2850  242.19   2955  251.63
#
#     2003    2003   2004    2004   2005         ...           2012    2012  \
# 2  Count    Rate  Count    Rate  Count         ...          Count    Rate
# 5   1944  165.85   2001  170.96   2112         ...           2157     185
# 6    824    70.3    778   66.47    851         ...            717   61.49
# 7   2768  236.15   2779  237.43   2963         ...           2874  246.49
#
#     2013    2013   2014    2014   2015    2015 Total for selection  \
# 2  Count    Rate  Count    Rate  Count    Rate               Count
# 5   1843  158.77   1608  139.14   1166  101.24               29957
# 6    694   59.79    583   50.45    466   40.46               10999
# 7   2537  218.55   2191  189.58   1632  141.71               40956
#
#   Total for selection
# 2                Rate
# 5              170.84
# 6               62.73
# 7              233.57
#
# [4 rows x 33 columns]

# %%
FinalAgedf
# Out:
#                                           Age: Under 1 Under 1 '1 - 4  '1 - 4  \
# 2                                  Statistics:   Count    Rate  Count    Rate
# 5               Poison/Overdose: Drugs/Alcohol    1481  127.64  19655  433.44
# 6  Poison/Overdose: Gas/Cleaners/Caustics/etc.    1125   96.96   7298  160.94
# 7                          Total for selection    2606   224.6  26953  594.38
#
#   '5 - 9 '5 - 9 '10 - 14 '10 - 14 Total for selection Total for selection
# 2  Count   Rate    Count     Rate               Count                Rate
# 5   2396  41.36     6425   106.25               29957              170.84
# 6   1252  21.61     1324    21.89               10999               62.73
# 7   3648  62.98     7749   128.14               40956              233.57

# %%
ax = plt.subplots()
ax.plot(FinalYeardf.columns, FinalYeardf["Rate"])
ax.set(xlabel="Time(Year:)", ylabel="Rate", title="Years vs Rate")
xlabel = "Count"
ylabel = "Rate"
ax.grid()
plt.show()

#FinalYeardf = pd.DataFrame(['Count', 'Rate'])

#data = FinalYeardf.columns
#for header in data:
 #   FinalYeardf = pd.FinalYeardf({'Count'})
  #  data.plot(x='Count',y=header)
   # FinalYeardf.plot(x='Rate', y='Year', kind='line')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-58-e451b0b400a1> in <module>()
#       1 ax = plt.subplots()
# ----> 2 ax.plot(FinalYeardf.columns, FinalYeardf["Rate"])
#       3 ax.set(xlabel="Time(Year:)", ylabel="Rate", title="Years vs Rate")
#       4 xlabel = "Count"
#       5 ylabel = "Rate"
#
# AttributeError: 'tuple' object has no attribute 'plot'

# %%
bar graphing\n",
    "#ya_axis = chtable1[\"Title:\"]\n",
    "#yb_axis = chtable1[\"Poison Case Rates\"]\n",
    "#x_axis = chtable1[\"Poison Case Counts\"]\n",
    ,
    "#plt.subplot(1, 2, 1)\n",
    "#plt.bar(x_axis, ya_axis)\n",
    "#, color='r', alpha=0.5, align=\"center\"\n",
    "#plt.subplot(1, 2, 2)\n",
    "#plt.bar(x_axis, yb_axis, color='r', alpha=0.5, align=\"center\")\n",
    "chtable1.plot.bar(x='Title:', y='Poison Case Rates', rot=0)\n",
    "plt.tight_layout()\n",
    "plt.show()"
   ]
# Out:
#   File "<ipython-input-57-805c689861c5>", line 1
#     bar graphing\n",
#                ^
# SyntaxError: invalid syntax

# %%
#FinalAgedf.drop(FinalAgedf.index[1], inplace = True)

# %%
#FinalYeardf.reset_index(inplace=True, drop=True)

# %%
#FinalYeardf

# %%
#FinalAgedf

# %%
# FinalYeardf.rename(columns={'Total for selection': 'Total Count', 'Total for selection': 'Total Rate'}, inplace=True)

# %%
# Changed Row 1 to header ChildPoisoningsby_Age
FinalAgedf = ChildPoisoningsby_Agedrop.rename(columns=ChildPoisoningsby_Agedrop.iloc[0]).drop(ChildPoisoningsby_Agedrop.index[0])

# %%
FinalAgedf.drop(FinalAgedf.index[1], inplace = True)

# %%
FinalAgedf.drop(FinalAgedf.index[0], axis=1)

# %%
FinalAgedf

# %%
# Merge our two data frames together
# combined_ChildPoisoning_data = pd.merge(ChildPoisoningsby_Age, ChildPoisoningsby_Year, on="Mechanism")
# combined_ChildPoisoning_data.head()

# %%
# Delete the duplicate 'Country Code' column and rename the first one back to 'Country Code'
# del combined_unemployed_data['Country Code_y']
# combined_unemployed_data = combined_unemployed_data.rename(columns={"Country Code_x":"Country Code"})
# combined_unemployed_data.head()

# %%
# Set the 'Country Code' to be our index for easy referencing of rows
combined_unemployed_data = combined_unemployed_data.set_index("Country Code")

# %%
# Collect the mean unemployment rates for the world
average_unemployment = combined_unemployed_data.mean()

# Collect the years where data was collected
years = average_unemployment.keys()

# %%
# Plot the world average as a line chart
world_avg, = plt.plot(years, average_unemployment, color="blue", label="World Average" )

# Plot the unemployment values for a single country
country_one, = plt.plot(years, combined_unemployed_data.loc['USA',["2010","2011","2012","2013","2014"]], 
                        color="green",label=combined_unemployed_data.loc['USA',"Country Name"])

# Create a legend for our chart
plt.legend(handles=[world_avg, country_one], loc="best")

# Show the chart
plt.show()

# %%
average_unemployment.plot(label="World Average")
combined_unemployed_data.loc['USA', "2010":"2014"].plot(label="United States")
plt.legend()
plt.show()

# %%
# %matplotlib notebook

# %%
# Import Dependencies
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Import our data into pandas from CSV
used_string = '../Resources/used_cars.csv'
used_car_df = pd.read_csv(used_string)

used_car_df

# %%
# Create a group based on the values in the 'maker' column
maker_group = used_car_df.groupby('maker')

# Count how many times each maker appears in our group
count_makers = maker_group['maker'].count()

count_makers

# %%
# Create a bar chart based off of the group series from before
count_chart = count_makers.plot(kind='bar')

# Set the xlabel and ylabel using class methods
count_chart.set_xlabel("Car Manufacturer")
count_chart.set_ylabel("Number of Cars")


plt.show()
plt.tight_layout()
